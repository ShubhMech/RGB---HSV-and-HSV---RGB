# %%
import cv2, numpy as np, matplotlib.pyplot as plt, matplotlib.image as img_

# %%
path=r"D:\Asus\Documents\Many-underestimate-white-dashed-lines.jpg"

# %%
col_img= img_.imread(path)

# %%
plt.imshow(col_img)

# %%
col_img.shape
# Out:
# (427, 640, 3)

# %%
import numpy as np
copy= np.copy(col_img)

# %%
plt.imshow(copy)

# %%
plt.imshow(col_img[:,:,0], cmap='hot')

# %%
plt.imshow(col_img[:,:,1], cmap='GnBu')

# %%
plt.imshow(col_img[:,:,2], cmap= 'rainbow')

# %%
copy
# Out:
# array([[[249, 250, 252],
#         [249, 250, 252],
#         [249, 250, 252],
#         ...,
#         [252, 254, 253],
#         [252, 254, 253],
#         [252, 254, 253]],
#
#        [[249, 250, 252],
#         [249, 250, 252],
#         [249, 250, 252],
#         ...,
#         [252, 254, 253],
#         [252, 254, 253],
#         [252, 254, 253]],
#
#        [[249, 250, 252],
#         [249, 250, 252],
#         [249, 250, 252],
#         ...,
#         [252, 254, 253],
#         [252, 254, 253],
#         [252, 254, 253]],
#
#        ...,
#
#        [[ 87,  99,  95],
#         [ 91, 102,  98],
#         [ 81,  92,  88],
#         ...,
#         [ 79,  83,  82],
#         [111, 115, 114],
#         [ 88,  92,  91]],
#
#        [[ 60,  72,  68],
#         [ 79,  90,  86],
#         [ 94, 105, 101],
#         ...,
#         [ 85,  89,  88],
#         [110, 114, 113],
#         [ 96, 100,  99]],
#
#        [[ 85,  97,  93],
#         [ 84,  95,  91],
#         [ 74,  85,  81],
# ...

# %%
copy[ (copy[:,:,0]<200) | (copy[:,:,1]<200) | (copy[:,:,2]<200) ] =1

# %%
plt.imshow(copy, cmap= 'rainbow')

# %%
cv2.imshow("Road!",col_img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
col_img1= cv2.imread(path)

# %%
cv2.imshow("Road!",col_img1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
plt.imshow(col_img1)

# %%
copy1=np.copy(col_img1)

# %%
x=copy1[:,:,0]

# %%
y=copy1[:,:,1]

# %%
z=copy1[:,:,2]

# %%
col_img1[:,:,2]=x

# %%
col_img1[:,:,0]=z

# %%
img_.imread(path)

# %%
plt.imshow(copy1)

# %%
plt.imshow(col_img1)
